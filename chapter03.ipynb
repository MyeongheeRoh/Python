# %%
a = b = c = d = 5

# %%
a + b + c + d
# Out:
# 20

# %%
a = b = c = d = 5
# d = '3'
if isinstance(a.__add__(b).__add__(c).__add__(d), type(NotImplemented)):
    print('error')
else:
    print('pass')
# Out:
# error

# %%
1+2+3+4+'dd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-fb17f36cb96e> in <module>
# ----> 1 1+23+4+'dd'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
e = " 100 + 100 "

# %%
eval(e) #문자열로 작성된 표현식 실행
# Out:
# 200

# %%
100 + 100
# Out:
# 200

# %%
s = """ #문자열에 함수 정의
def add_ (x,y) :
    return x+y
"""

# %%
exec(s) #문자열 실행해도 반환 값이 없음

# %%
add_(10,10) #exec함수 실행으로 add 함수가 만들어지고 호출하여 실행
# Out:
# 20

# %%
r = range(5) #기본 시작점 0,간격 1,끝점 5

# %%
r
# Out:
# range(0, 5)

# %%
for i in r : #순환문에서 원소 하나씩 꺼내서 처리
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x = 100

# %%
y = "2 *x ** 2 + 4"

# %%
eval(y)
# Out:
# 20004

# %%
z = "y1 = 2 *x ** 2+ 4"

# %%
exec(z)

# %%
globals()['y1']
# Out:
# 20004

# %%
y1
# Out:
# 20004

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'a = b = c = d = 5',
#   'a + b + c + d',
#   'a.__add__(b).__add__(c).__add__(d)',
#   "a.__add__(b).__add__(c).__add__('asd')",
#   "type(a.__add__(b).__add__(c).__add__('asd'))",
#   "1+23+4+'dd'",
#   "a.__add__(b).__add__(c).__add__('asd')",
#   "if isinstance(a.__add__(b).__add__(c).__add__('asd'), NotImplemented)",
#   "if isinstance(a.__add__(b).__add__(c).__add__('asd'), NotImplemented):\n    print(1)",
#   "if isinstance(a.__add__(b).__add__(c).__add__('asd'), type(NotImplemented)):\n    print(1)",
#   "a = b = c = d = 5\nd = '3'\nif isinstance(a.__add__(b).__add__(c).__add__(d), type(NotImplemented)):\n    print(1)",
# ...
